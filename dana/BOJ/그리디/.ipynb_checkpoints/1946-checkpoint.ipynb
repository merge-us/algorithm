# %%
t = int(input())
n = []
datas = []
result = []

for _ in range(t):
    num = int(input())
    n.append(num)
    
    for _ in range(num):
        data = [list(map(int,input().split()))]
        datas.append(data)

for i in range(t):
    for j in datas[i]:
# Out:
#  2
#  2
#  2 2
#  2 2
#  3
#  3 3
#  3 3
#  3 3
# [[[2, 2]], [[2, 2]], [[3, 3]], [[3, 3]], [[3, 3]]]
