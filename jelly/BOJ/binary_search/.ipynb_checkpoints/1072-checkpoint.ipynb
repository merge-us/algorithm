# %%
import math

x, y = map(int, input().split())

z = math.floor(y / x * 100)

start = 0
end = 1e9

result = 0
while start <= end:
    mid = (start + end) // 2

    current_rate = math.floor((y + mid) / (x + mid) * 100)

    if current_rate > target_rate:
        result = mid
        end = mid - 1
    else:
        start = mid + 1


print(result if result > 0 else -1)
# Out:
#  53 42
# 2.0

# %%
import sys

x, y = map(int, input().split())

z = (y * 100) // x
if z >= 99:
    print(-1)
    sys.exit()

start = 0
end = 1000_000_000

result = -1
while start <= end:
    mid = (start + end) // 2

    current_rate = (y + mid) * 100 // (x + mid)

    if current_rate > z:
        result = mid
        end = mid - 1
    else:
        start = mid + 1


print(result)
# Out:
#  1000000000 470000000
# 19230770

# %%
x, y = map(int, input().split())
z = (y * 100) // x

if z >= 99:
    print(-1)
else:
    start, end = 0, 1_000_000_000
    result = -1
    
    while start <= end:
        mid = (start + end) // 2
    
        new_z = (y + mid) * 100 // (x + mid)
        if new_z > z:
            result = mid
            end = mid - 1
        else:
            start = mid + 1
    
    print(result)
