# %%
n = int(input())

edges = list(map(int, input().split()))
prices = list(map(int, input().split()))

result = 0
for i in range(n - 1):
    if prices[i] < prices[i + 1]:
        prices[i + 1] = prices[i]

    result += prices[i] * edges[i]

print(result)
# Out:
#  4
#  3 3 4
#  1 1 1 1
# 10

# %%
n = int(input())
distances = list(map(int, input().split()))
prices = list(map(int, input().split()))

total_cost = 0
min_price = prices[0]

for i in range(n - 1):
    total_cost += min_price * distances[i]
    min_price = min(min_price, prices[i + 1])

print(total_cost)
