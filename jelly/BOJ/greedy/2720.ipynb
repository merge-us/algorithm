# %%
t = int(input())
coins = [25, 10, 5, 1]
    
for _ in range(t):
    change = int(input())

    for coin in coins:
        count = 0
        count += change // coin
        change %= coin
        print(count, end=" ")
# Out:
#  194
# 7 1 1 4

# %%
t = int(input())
coins = [25, 10, 5, 1]
    
for _ in range(t):
    change = int(input())
    for coin in coins:
        print(change // coin, end=" ")
        change %= coin
    print()
